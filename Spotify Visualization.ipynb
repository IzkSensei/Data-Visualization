# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
from pandas.plotting import scatter_matrix

# %%
plt.style.use('seaborn')

# %%
path = 'tracks.csv'
tracks = pd.read_csv(path)
tracks.head()
tracks.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  586672.000000  5.866720e+05  ...  586672.000000   586672.000000
# mean       27.570053  2.300512e+05  ...     118.464857        3.873382
# std        18.370642  1.265261e+05  ...      29.764108        0.473162
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%        13.000000  1.750930e+05  ...      95.600000        4.000000
# 50%        27.000000  2.148930e+05  ...     117.384000        4.000000
# 75%        41.000000  2.638670e+05  ...     136.321000        4.000000
# max       100.000000  5.621218e+06  ...     246.381000        5.000000
#
# [8 rows x 15 columns]

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
tracks.hist(figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(16,8))
corr = tracks.corr()
sns.heatmap(corr,annot=True)

# %%
plt.figure(figsize=(16, 8))
ax = sns.jointplot(x=tracks['loudness'],y=tracks['popularity'],data=tracks,s=10)

# %%
genre=pd.read_csv('data_by_genres_o.csv')
genre.head()
# Out:
#    mode                  genres  acousticness  ...   valence  popularity  key
# 0     1  21st century classical      0.979333  ...  0.103783   27.833333    6
# 1     1                   432hz      0.494780  ...  0.221750   52.500000    5
# 2     1                   8-bit      0.762000  ...  0.975000   48.000000    7
# 3     1                      []      0.651417  ...  0.513604   20.859882    7
# 4     1              a cappella      0.676557  ...  0.448249   45.820071    7
#
# [5 rows x 14 columns]

# %%
genre.hist(figsize=(10,10))
plt.show()

# %%
genre.nunique()
# Out:
# mode                   2
# genres              2973
# acousticness        2802
# danceability        2725
# duration_ms         2872
# energy              2781
# instrumentalness    2733
# liveness            2715
# loudness            2872
# speechiness         2720
# tempo               2872
# valence             2746
# popularity          2186
# key                   12
# dtype: int64

# %%
plt.figure(figsize=(16, 8))
corr = genre.corr()
sns.heatmap(corr,annot=True)

# %%
plt.figure(figsize=(16, 8))
ax = sns.jointplot(x=genre['loudness'],y=genre['popularity'],data=genre,s=5)

# %%
path = 'data_by_year_o.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    mode  year  acousticness  ...   valence  popularity  key
# 0     1  1921      0.886896  ...  0.379327    0.653333    2
# 1     1  1922      0.938592  ...  0.535549    0.140845   10
# 2     1  1923      0.957247  ...  0.625492    5.389189    0
# 3     1  1924      0.940200  ...  0.663725    0.661017   10
# 4     1  1925      0.962607  ...  0.621929    2.604317    5
#
# [5 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              100 non-null    int64
#  1   year              100 non-null    int64
#  2   acousticness      100 non-null    float64
#  3   danceability      100 non-null    float64
#  4   duration_ms       100 non-null    float64
#  5   energy            100 non-null    float64
#  6   instrumentalness  100 non-null    float64
#  7   liveness          100 non-null    float64
#  8   loudness          100 non-null    float64
#  9   speechiness       100 non-null    float64
#  10  tempo             100 non-null    float64
#  11  valence           100 non-null    float64
#  12  popularity        100 non-null    float64
#  13  key               100 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.1 KB

# %%
sns.color_palette("tab10")
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
names = data[["acousticness","danceability","energy", "instrumentalness", 
               "liveness","tempo", "valence", "loudness", "speechiness", "year"]].\
groupby("year").mean().sort_values(by="year").reset_index()

plt.figure(figsize=(20,12))

lines = ["acousticness","danceability","energy", 
         "instrumentalness", "liveness", "valence", "speechiness"]
for line in lines:
    ax = sns.lineplot(x='year',palette = 'tab10', y=line,data=names)
    
    
plt.ylabel("value")
plt.legend(lines)

# %%
import plotly.express as px

# %%
scaled_year=data.copy()
scaled_year['acousticness'] = scaled_year['acousticness'] / scaled_year['acousticness'].max()
scaled_year['danceability'] = scaled_year['danceability'] / scaled_year['danceability'].max()
scaled_year['duration_ms'] = scaled_year['duration_ms'] / scaled_year['duration_ms'].max()
scaled_year['energy'] = scaled_year['energy'] / scaled_year['energy'].max()
scaled_year['instrumentalness'] = scaled_year['instrumentalness'] / scaled_year['instrumentalness'].max()
scaled_year['liveness'] = scaled_year['liveness'] / scaled_year['liveness'].max()
scaled_year['speechiness'] = scaled_year['speechiness'] / scaled_year['speechiness'].max()
scaled_year['tempo'] = scaled_year['tempo'] / scaled_year['tempo'].max()
scaled_year['valence'] = scaled_year['valence'] / scaled_year['valence'].max()
scaled_year['popularity'] = scaled_year['popularity'] / scaled_year['popularity'].max()
scaled_year['loudness'] = scaled_year['loudness'] / scaled_year['loudness'].min()
scaled_year['year'] = scaled_year['year'].astype(str)

# %%
scaled_year.drop(["key","mode"],axis=1,inplace=True)
scaled_year = scaled_year.melt("year")

# %%
scaled_year.head()
# Out:
#    year      variable     value
# 0  1921  acousticness  0.921348
# 1  1922  acousticness  0.975052
# 2  1923  acousticness  0.994432
# 3  1924  acousticness  0.976722
# 4  1925  acousticness  1.000000

# %%
fig = px.line_polar(scaled_year, r="value",theta="variable",line_close=True,
             animation_frame="year",template="xgridoff",range_r = (0,1))
fig.update_traces(fill='toself')
fig.update_layout(font_size=15)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e146e09-d097-47f3-b5d4-26324b0a50d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e146e09-d097-47f3-b5d4-26324b0a50d9")) {
#                     Plotly.newPlot(
#                         '7e146e09-d097-47f3-b5d4-26324b0a50d9',
# ...

# %%
data['scale'] = pd.qcut(data['popularity'], q=4)
# "popularity VS "energy" by "years" and with size "loudness_range"
plt.subplots(1,1,figsize=(14.70, 8.27))
sns.scatterplot(x="energy", y="loudness",
                hue="year", size="scale",
                palette="ch:r=-.2,d=.3_r",
                sizes=(20, 200), linewidth=0,
                data(

# %%
data['loudness_range'] = pd.qcut(data['loudness'], q=4)
# "popularity VS "energy" by "years" and with size "loudness_range"
plt.subplots(1,1,figsize=(14.70, 8.27))
sns.scatterplot(x="energy", y="popularity",
                hue="year", size="loudness_range",
                palette="ch:r=-.2,d=.3_r",
                sizes=(20, 200), linewidth=0,
                data=data.sample(frac=500, replace=True).compute())
